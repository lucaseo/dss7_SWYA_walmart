# %% [markdown]
# # Fast Campus Data Science School Team Project
#
# - Team: Team B-2 SWYA (김선웅, 백윤아, 서원영)
#
# <img src="https://github.com/novdov/dss7_SWYA_walmart/blob/master/main/data/walmart.jpg?raw=true", width="700">
#
# ## Walmart Recruiting: Trip Type Classification

# %% [markdown]
# ### Objective:
#
# - Trip Type Classification of each customers based on thier shopping data

# %% [markdown]
# ### Data Description:
#
# - train : 647054 rows, 7 columns
# - test : 653646 rows, 6 columns
#
# | Index | Feature               | Feature Description                                  | Unique Value |
# |-------|-----------------------|----------------------------------------------|--------|
# | 1     | TripType              | A categorical id representing the type of shopping trip the customer made.                                       | 38     |
# | 2     | VisitNumber           | An id corresponding to a single trip by a single customer                              | 95674  |
# | 3     | Weekday               | The weekday of the trip                    | 7      |
# | 4     | Upc                   | The UPC number of the product purchased                  | 97715  |
# | 5     | ScanCount             | The number of the given item that was purchased. A negative value indicates a product return          | 39     |
# | 6     | DepartmentDescription | A high-level description of the item's department                                | 69     |
# | 7     | FinelineNumber        | A more refined category for each of the products, created by Walmart | 5196   |

# %% [markdown]
# ### UPC code description
# <img src="https://github.com/novdov/dss7_SWYA_walmart/blob/master/main/data/upc.png?raw=true", width="550">

# %% [markdown]
# ### Evaluation : Multi-class log loss (Cross Entropy)
#  $$-\frac{1}{N}\sum_{i=1}^N\sum_{j=1}^My_{ij}\log(p_{ij})$$
#
# - $N$ : the number of visits in the test set
# - $M$ : the number of trip types
# - $\log$ : natural logarithm
# - $y_{ij}$ : 1 if observation i is of class j and 0 otherwise
# - $p_{ij}$ : the predicted probability that observation i belongs to class j

# %% [markdown]
# ## Contents
#
# - **[1. EDA & Preprocessing](#1.-EDA-&-Preprocessing)**
# <br>
#
# - **[2. Feature Engineering](#2.-Feature-Engineering)**
#     - UPC decoding
#     - ScanCount seperation
#     - Feature encoding
#     - Dummy variables
#     - Identifing the most frequently purchased items per VisitNumber
#
# <br>
# - **3. [Modeling](#3.-Modeling)**
#     - Random Forest
#     - XGBoost
#
# ### 4. Results
#
# ### 5. Kaggle Submission
# - Total Teams : 1,047 teams
# - Final Score : 0.79154
# - Leaderboard : 294/1,047 (top 30%)
#
# ### 6. Lesson
#
#
# [Take a first look at the data](#Take-a-first-look-at-the-data)

# %% [markdown]
# # 1. EDA & Preprocessing

# %%
import numpy as np
import pandas as pd
from collections import Counter

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %config InlineBackend.figure_formats = {'png', 'retina'}

# %%
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
print(train.shape)
train.tail()
# Out:
# (647054, 7)
#         TripType  VisitNumber Weekday           Upc  ScanCount  \
# 647049        39       191346  Sunday  3.239000e+10          1
# 647050        39       191346  Sunday  7.874205e+09          1
# 647051        39       191346  Sunday  4.072000e+03          1
# 647052         8       191347  Sunday  4.190008e+09          1
# 647053         8       191347  Sunday  3.800060e+09          1
#
#        DepartmentDescription  FinelineNumber
# 647049          PHARMACY OTC          1118.0
# 647050          FROZEN FOODS          1752.0
# 647051               PRODUCE          4170.0
# 647052                 DAIRY          1512.0
# 647053     GROCERY DRY GOODS          3600.0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 647054 entries, 0 to 647053
# Data columns (total 7 columns):
# TripType                 647054 non-null int64
# VisitNumber              647054 non-null int64
# Weekday                  647054 non-null object
# Upc                      642925 non-null float64
# ScanCount                647054 non-null int64
# DepartmentDescription    645693 non-null object
# FinelineNumber           642925 non-null float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 34.6+ MB

# %% [markdown]
# ### Missing Values

# %%
plt.figure(figsize=(7, 5))
train.isnull().sum().plot(kind='bar')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# - Upc, DepartmentDescription, FinelineNumber에 Missing Values 존재
# - Upc와 FinelineNumber의 Missing Values는 동시에 나타남
# - Missing Value 제거 시 사라지는 VisitNumber 존재
# - Feature Engineering에서 VisitNumber에 대한 테이블로 변경
# - 최종 모델링 시 Nan은 0으로 처리

# %% [markdown]
# ### Encode Weekday (Labeling)

# %%
wd = {"Monday": 0, "Tuesday": 1, "Wednesday": 2, "Thursday": 3, 
      "Friday": 4, "Saturday": 5, "Sunday": 6}
train["Weekday"] = train["Weekday"].apply(lambda x: wd[x])
test["Weekday"] = test["Weekday"].apply(lambda x: wd[x])

# %%
plt.figure(figsize=(14, 3))

sns.heatmap(data=pd.crosstab(train["Weekday"],
                             train["TripType"], 
                             values=train["VisitNumber"],
                             aggfunc='count', 
                             normalize="columns"), cmap="ocean_r")
plt.yticks(range(0,7), list(wd.keys()), rotation="horizontal")
plt.title("Distribution of Triptype on Weekday", fontsize=13)
plt.show()

# %% [markdown]
# - TripType 14는 월, 금/토에 많이 나타남
# - Feature에 반영 (One-Hot Encoding)

# %% [markdown]
# ### Uneven Distribution of TripType

# %%
plt.figure(figsize=(12, 5))

sns.set_style('whitegrid')
np.sort(train.TripType.unique())
train_triptypes = train.drop_duplicates("VisitNumber")
a = train_triptypes["TripType"]
a = a.value_counts()
a.plot(kind='bar', color="lightseagreen")
plt.title("Number of TripType Occurence by VisitNumber", fontsize=13)
plt.xlabel("TripType")

plt.show()

# %%
train_40 = train[train["TripType"]==40]
train_40["DepartmentDescription"].value_counts()[:10]
# Out:
# GROCERY DRY GOODS           32639
# DSD GROCERY                 22157
# DAIRY                       17354
# PRODUCE                     16704
# PERSONAL CARE                9911
# FROZEN FOODS                 9307
# HOUSEHOLD CHEMICALS/SUPP     8093
# COMM BREAD                   5968
# HOUSEHOLD PAPER GOODS        5712
# PHARMACY OTC                 4569
# Name: DepartmentDescription, dtype: int64

# %% [markdown]
# ### Most Frequent & Least Frequent TripType

# %%
fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(121)
type_8 = train[train.TripType == 8]
type_8_items = type_8[["TripType","DepartmentDescription"]]
type_8_items.DepartmentDescription.value_counts().head().plot(kind="bar", rot=45, 
                                        title="TripType 8", color="seagreen")
ax1 = fig.add_subplot(122)
type_14 = train[train.TripType == 14]
type_14_items = type_14[["TripType","DepartmentDescription"]]
type_14_items.DepartmentDescription.value_counts().head().plot(kind="bar", rot=45, 
                                        title="TripType 14", color="lightcoral")

fig.suptitle("Distrubution of DepartmentDescription each TripType", fontsize=13)
plt.xticks(fontsize=10)
plt.show()

# %%
trip_desc = pd.crosstab(train["TripType"], 
                        train["DepartmentDescription"], 
                        values=train["ScanCount"], 
                        aggfunc="count", 
                        normalize="index")

plt.figure(figsize=(18, 9))
sns.heatmap(trip_desc, linecolor="lightgrey", linewidths=0.02, cmap="RdPu", alpha=.8)
plt.title("Distrubution of DepartmentDescription on TripTypes", fontsize=13)
plt.show()

# %% [markdown]
# - 비슷한 Department에서 물건 구매시 TripType 분류에 영향을 미치는 것으로 보임
# - 하나의 Department에서만 구매한 것이 아닌 여러 Department에서 구매함
# - 복수의 Department 방문 여부를 Feature에 반영 (CategoryCounts)

# %%
train_plot = train[["TripType", "ScanCount"]]
plot_grouped = train_plot.groupby("TripType", as_index=False).sum()

f, (ax, ax2) = plt.subplots(2, 1, sharex=True, figsize=(12, 5))
sns.barplot(x="TripType", y="ScanCount", data=plot_grouped, ax=ax)
sns.barplot(x="TripType", y="ScanCount", data=plot_grouped, ax=ax2)

ax.set_ylim(100000, 210000)
ax2.set_ylim(-2000, 2000)
ax.xaxis.label.set_visible(False)
ax.yaxis.label.set_visible(False)
ax2.yaxis.label.set_visible(False)

ax.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax.xaxis.tick_top()
ax.tick_params(labeltop='off') 
ax2.xaxis.tick_bottom()

d = .005

kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((-d, +d), (-d, +d), **kwargs)        
ax.plot((1 - d, 1 + d), (-d, +d), **kwargs)  

kwargs.update(transform=ax2.transAxes) 
ax2.plot((-d, +d), (1 - d, 1 + d), **kwargs)
ax2.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs) 

f.text(0, 0.5, 'ScanCount', va='center', rotation='vertical', fontsize=11)
f.text(0.5, 1, 'ScanCount', va='center', rotation='horizontal', fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# - TripType 999는 반품을 위한 방문이라고 생각됨
# - Return 여부를 Feature에 반영 (Return)
# - ScanCount를 실제 판매수량과 반품으로 나누어서 Feature에 반영 (Pos_Sum, Neg_Sum)

# %% [markdown]
# # 2. Feature Engineering

# %% [markdown]
# ### Decode company code from UPC

# %%
def float_to_str(obj):
    """
    Convert Upc code from float to string
    Use this function by applying lambda
    :param obj: "Upc" column of DataFrame
    :return: string converted Upc removing dot.
    """
    while obj != "nan":
        obj = str(obj).split(".")[0]
        return obj

# %%
def company(x):
    """
    Return company code from given Upc code.
    :param x: "Upc" column of DataFrame
    :return: company code
    """
    try:
        p = x[:6]
        if p == "000000":
            return x[-5]
        return p
    except:
        return -9999

# %%
train["Upc"] = train.Upc.apply(float_to_str)
test["Upc"] = test.Upc.apply(float_to_str)

train["company"] = train.Upc.apply(company) 
test["company"] = test.Upc.apply(company)

# %% [markdown]
# ### Return Indicator

# %%
train.loc[train["ScanCount"] < 0, "Return"] = 1
train.loc[train["Return"] != 1, "Return"] = 0

test.loc[test["ScanCount"] < 0, "Return"] = 1
test.loc[test["Return"] != 1, "Return"] = 0

# %% [markdown]
# ### Positive ScanCount (The number of sold)

# %%
train["Pos_Sum"] = train["ScanCount"]
test["Pos_Sum"] = test["ScanCount"]

train.loc[train["Pos_Sum"] < 0, "Pos_Sum"] = 0
test.loc[test["Pos_Sum"] < 0, "Pos_Sum"] = 0

# %% [markdown]
# ### Negative ScanCount (The number of returns)

# %%
train["Neg_Sum"] = train["ScanCount"]
test["Neg_Sum"] = test["ScanCount"]

train.loc[train["Neg_Sum"] > 0, "Neg_Sum"] = 0
test.loc[test["Neg_Sum"] > 0, "Neg_Sum"] = 0

# %%
print(train.shape)
train.tail()
# Out:
# (647054, 11)
#         TripType  VisitNumber  Weekday          Upc  ScanCount  \
# 647049        39       191346        6  32390001778          1
# 647050        39       191346        6   7874205336          1
# 647051        39       191346        6         4072          1
# 647052         8       191347        6   4190007664          1
# 647053         8       191347        6   3800059655          1
#
#        DepartmentDescription  FinelineNumber company  Return  Pos_Sum  Neg_Sum
# 647049          PHARMACY OTC          1118.0  323900     0.0        1        0
# 647050          FROZEN FOODS          1752.0  787420     0.0        1        0
# 647051               PRODUCE          4170.0    4072     0.0        1        0
# 647052                 DAIRY          1512.0  419000     0.0        1        0
# 647053     GROCERY DRY GOODS          3600.0  380005     0.0        1        0

# %% [markdown]
# ### FinelineNumber most frequently appear

# %%
def mode(x):
    counts = Counter(x)
    max_count = max(counts.values())
    ls = [x_i for x_i, count in counts.items() if count == max_count]
    return ls[0]

# %%
train_fineline = train[["VisitNumber", "FinelineNumber"]]
train_fineline = train_fineline.groupby("VisitNumber", as_index=False).agg(mode)
train_fineline.rename(columns={"FinelineNumber": "MF_FinelineNumber"}, inplace=True)

test_fineline = test[["VisitNumber", "FinelineNumber"]]
test_fineline = test_fineline.groupby("VisitNumber", as_index=False).agg(mode)
test_fineline.rename(columns={"FinelineNumber": "MF_FinelineNumber"}, inplace=True)

# %% [markdown]
# ### The number of UPC and  FinelineNumber for each VisitNumber

# %%
train_upc_fine = train[["VisitNumber", "Upc", "FinelineNumber"]]
test_upc_fine = test[["VisitNumber", "Upc", "FinelineNumber"]]

train_upc_fine_group = train_upc_fine.groupby("VisitNumber", as_index=False).count()
train_upc_fine_group.rename(columns={"Upc": "N_Upc", 
                                     "FinelineNumber": "N_FinelineNumber"}, inplace=True)
test_upc_fine_group = test_upc_fine.groupby("VisitNumber", as_index=False).count()
test_upc_fine_group.rename(columns={"Upc": "N_Upc", 
                                    "FinelineNumber": "N_FinelineNumber"}, inplace=True)

# %%
train.drop(["Upc", "FinelineNumber"], axis=1, inplace=True)
test.drop(["Upc", "FinelineNumber"], axis=1, inplace=True)

# %% [markdown]
# ### One-Hot Encoding of DepartmentDescription

# %%
train_dd = pd.get_dummies(train["DepartmentDescription"])
test_dd = pd.get_dummies(test["DepartmentDescription"])

train_dd = pd.concat([train[["VisitNumber"]], train_dd], axis=1)
test_dd = pd.concat([test[["VisitNumber"]], test_dd], axis=1)

train_dd = train_dd.groupby("VisitNumber", as_index=False).sum()
test_dd = test_dd.groupby("VisitNumber", as_index=False).sum()

# %%
train_dd.tail()
# Out:
#        VisitNumber  1-HR PHOTO  ACCESSORIES  AUTOMOTIVE  BAKERY  \
# 95669       191343           0            0           0       0
# 95670       191344           0            0           0       0
# 95671       191345           0            0           0       0
# 95672       191346           0            0           0       0
# 95673       191347           0            0           0       0
#
#        BATH AND SHOWER  BEAUTY  BEDDING  BOOKS AND MAGAZINES  BOYS WEAR  \
# 95669                0       0        0                    0          0
# 95670                0       4        0                    0          0
# 95671                0       1        0                    0          0
# 95672                0       0        0                    0          0
# 95673                0       0        0                    0          0
#
#          ...     SEAFOOD  SEASONAL  SERVICE DELI  SHEER HOSIERY  SHOES  \
# 95669    ...           0         0             0              0      0
# 95670    ...           0         0             0              0      0
# 95671    ...           0         0             0              0      0
# 95672    ...           0         0             0              0      0
# 95673    ...           0         0             0              0      0
#
#        SLEEPWEAR/FOUNDATIONS  SPORTING GOODS  SWIMWEAR/OUTERWEAR  TOYS  \
# 95669                      0               0                   0     0
# 95670                      0               0                   0     0
# 95671                      0               0                   0     0
# 95672                      0               0                   0     0
# 95673                      0               0                   0     0
#
#        WIRELESS
# 95669         0
# 95670         1
# 95671         0
# 95672         0
# 95673         0
#
# [5 rows x 69 columns]

# %% [markdown]
# ### FinelineNumber most frequently appear

# %%
train_company = train[["VisitNumber", "company"]]
test_company = test[["VisitNumber", "company"]]

train_company = train_company.groupby("VisitNumber", as_index=False).agg(mode)
test_company = test_company.groupby("VisitNumber", as_index=False).agg(mode)

# %% [markdown]
# ### Pivot data by VisitNumber

# %%
train_by_sum = train[["VisitNumber", "ScanCount", "Pos_Sum", "Neg_Sum"]]
test_by_sum = test[["VisitNumber", "ScanCount", "Pos_Sum", "Neg_Sum"]]

train_by_sum = train_by_sum.groupby("VisitNumber", as_index=False).sum()
test_by_sum = test_by_sum.groupby("VisitNumber", as_index=False).sum()

train_by_max = train[["TripType", "VisitNumber", "Weekday", "Return"]]
test_by_max = test[["VisitNumber", "Weekday", "Return"]]

train_by_max = train_by_max.groupby("VisitNumber", as_index=False).max()
test_by_max = test_by_max.groupby("VisitNumber", as_index=False).max()

# %%
train = train_by_sum.merge(train_by_max, on=["VisitNumber"])
train = train.merge(train_dd, on=["VisitNumber"])
train = train.merge(train_company, on=["VisitNumber"])
train = train.merge(train_fineline, on=["VisitNumber"])
train = train.merge(train_upc_fine_group, on=["VisitNumber"])

test = test_by_sum.merge(test_by_max, on=["VisitNumber"])
test = test.merge(test_dd, on=["VisitNumber"])
test = test.merge(test_company, on=["VisitNumber"])
test = test.merge(test_fineline, on=["VisitNumber"])
test = test.merge(test_upc_fine_group, on=["VisitNumber"])

# %% [markdown]
# - Remove DepartmentDescription not shown in test data
# - Segregate features & target

# %%
y = train["TripType"]
train = train.drop(["TripType", "HEALTH AND BEAUTY AIDS"], axis=1)

# %% [markdown]
# ### The counts of DepartmentDescription for each VistNumber

# %%
def category_counts(data):
    """
    Count total number of unique DepartmentDescription made on each trip.
    """
    counts = []
    for array in np.asarray(data.loc[:, "1-HR PHOTO":"WIRELESS"]):
        count = 0
        for item in array:
            if item > 0:
                count += 1
        counts.append(count)
    cat_counts = pd.DataFrame(counts)
    cat_counts = cat_counts.rename(columns={0: "CategoryCount"})
    cat_counts = cat_counts.set_index(data.index)

    data.insert(6, "CategoryCounts", cat_counts)

    return data

# %%
# from walmart_utils import category_counts
# %time train = category_counts(train)
# %time test = category_counts(test)
# Out:
# CPU times: user 12.6 s, sys: 135 ms, total: 12.7 s
# Wall time: 13.7 s
# CPU times: user 12.1 s, sys: 109 ms, total: 12.2 s
# Wall time: 12.7 s

# %% [markdown]
# ### Ratio of number of UPC and FinelineNumber

# %%
train["Upc_FLN"] = train["N_Upc"] / train["N_FinelineNumber"]
test["Upc_FLN"] = test["N_Upc"] / test["N_FinelineNumber"]

# %% [markdown]
# ### One-Hot Encoding of Weeday and Return

# %%
train = pd.get_dummies(train, columns=["Weekday", "Return"])
test = pd.get_dummies(test, columns=["Weekday", "Return"])

# %%
vn = test[["VisitNumber"]]
train.drop("VisitNumber", axis=1, inplace=True)
test.drop("VisitNumber", axis=1, inplace=True)

# %% [markdown]
# ### Replace Null Value, Inf Value with 0

# %%
train.replace(np.inf, 0, inplace=True)
train.fillna(value=0, inplace=True)

test.replace(np.inf, 0, inplace=True)
test.fillna(value=0, inplace=True)

# %% [markdown]
# ### Final Data
# - 86 features

# %% [markdown]
# # 3. Modeling
#
# - Random Forest
# - XGBoost

# %% [markdown]
# ### Final Features (Total 86)
#
# - ScanCount
# - Return (dummies)
# - Pos_Sum
# - Neg_Sum
# - CategoryCounts
# - DepartmentDescription (dummies)
# - Company code
# - MF_Fineline (Most Frequent FinelineNumbers)
# - MF_DepartmentDescription (Most Frequent DepartmentDescription)
# - N_UPC (The number of UPC
# - N_FinelineNumber (The number of FinelineNumber)
# - UPC_FLN (N_UPC / N_FinelineNumber)
# - Weekday (dummies)

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
label_enc = LabelEncoder().fit(y)
y_labeled = label_enc.transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    train, y_labeled, random_state=0)

# %%
dtrain = xgb.DMatrix(X_train.values, label=y_train)
dtest = xgb.DMatrix(X_test.values, label=y_test)

# %%
num_boost_round = 300
params = {'objective': 'multi:softprob', 
          'eval_metric': 'mlogloss',
          'num_class':38, 
          'max_delta_step': 3, 
          'eta': 0.2}

evals = [(dtrain, 'train'), (dtest, 'eval')]

bst = xgb.train(params=params,  
                dtrain=dtrain, 
                num_boost_round=num_boost_round, 
                evals=evals,
                early_stopping_rounds=10,)
# Out:
# [0]	train-mlogloss:3.07027	eval-mlogloss:3.07895
# Multiple eval metrics have been passed: 'eval-mlogloss' will be used for early stopping.
#
# Will train until eval-mlogloss hasn't improved in 10 rounds.
# [1]	train-mlogloss:2.56753	eval-mlogloss:2.58796
# [2]	train-mlogloss:2.16513	eval-mlogloss:2.19862
# [3]	train-mlogloss:1.87062	eval-mlogloss:1.91257
# [4]	train-mlogloss:1.6757	eval-mlogloss:1.72497
# [5]	train-mlogloss:1.53132	eval-mlogloss:1.58749
# [6]	train-mlogloss:1.41721	eval-mlogloss:1.47881
# [7]	train-mlogloss:1.32225	eval-mlogloss:1.38985
# [8]	train-mlogloss:1.24535	eval-mlogloss:1.31855
# [9]	train-mlogloss:1.17935	eval-mlogloss:1.25733
# [10]	train-mlogloss:1.12313	eval-mlogloss:1.20616
# [11]	train-mlogloss:1.07468	eval-mlogloss:1.16255
# [12]	train-mlogloss:1.0333	eval-mlogloss:1.12568
# [13]	train-mlogloss:0.994625	eval-mlogloss:1.09155
# [14]	train-mlogloss:0.962195	eval-mlogloss:1.06328
# [15]	train-mlogloss:0.933556	eval-mlogloss:1.03832
# [16]	train-mlogloss:0.908205	eval-mlogloss:1.01705
# [17]	train-mlogloss:0.884684	eval-mlogloss:0.997824
# [18]	train-mlogloss:0.864079	eval-mlogloss:0.981041
# [19]	train-mlogloss:0.844868	eval-mlogloss:0.966236
# [20]	train-mlogloss:0.827593	eval-mlogloss:0.952816
# [21]	train-mlogloss:0.812252	eval-mlogloss:0.940846
# [22]	train-mlogloss:0.797282	eval-mlogloss:0.929613
# [23]	train-mlogloss:0.783632	eval-mlogloss:0.919398
# [24]	train-mlogloss:0.771574	eval-mlogloss:0.911103
# [25]	train-mlogloss:0.759616	eval-mlogloss:0.902572
# [26]	train-mlogloss:0.748657	eval-mlogloss:0.894919
# [27]	train-mlogloss:0.738902	eval-mlogloss:0.888269
# [28]	train-mlogloss:0.728596	eval-mlogloss:0.881357
# [29]	train-mlogloss:0.719088	eval-mlogloss:0.875307
# [30]	train-mlogloss:0.711078	eval-mlogloss:0.870439
# [31]	train-mlogloss:0.703331	eval-mlogloss:0.866154
# [32]	train-mlogloss:0.696114	eval-mlogloss:0.86202
# [33]	train-mlogloss:0.689427	eval-mlogloss:0.858228
# [34]	train-mlogloss:0.682698	eval-mlogloss:0.854998
# [35]	train-mlogloss:0.675678	eval-mlogloss:0.850995
# [36]	train-mlogloss:0.669335	eval-mlogloss:0.847415
# [37]	train-mlogloss:0.663487	eval-mlogloss:0.844305
# [38]	train-mlogloss:0.658104	eval-mlogloss:0.841678
# [39]	train-mlogloss:0.652942	eval-mlogloss:0.839174
# [40]	train-mlogloss:0.648071	eval-mlogloss:0.836859
# [41]	train-mlogloss:0.643311	eval-mlogloss:0.835001
# [42]	train-mlogloss:0.638139	eval-mlogloss:0.833055
# [43]	train-mlogloss:0.633743	eval-mlogloss:0.831146
# [44]	train-mlogloss:0.629232	eval-mlogloss:0.82928
# [45]	train-mlogloss:0.625282	eval-mlogloss:0.827465
# [46]	train-mlogloss:0.62108	eval-mlogloss:0.825598
# [47]	train-mlogloss:0.617169	eval-mlogloss:0.824116
# [48]	train-mlogloss:0.613149	eval-mlogloss:0.822777
# [49]	train-mlogloss:0.609296	eval-mlogloss:0.821639
# [50]	train-mlogloss:0.605376	eval-mlogloss:0.820051
# [51]	train-mlogloss:0.601678	eval-mlogloss:0.818636
# [52]	train-mlogloss:0.598221	eval-mlogloss:0.817297
# [53]	train-mlogloss:0.59458	eval-mlogloss:0.815866
# [54]	train-mlogloss:0.591497	eval-mlogloss:0.814909
# [55]	train-mlogloss:0.588314	eval-mlogloss:0.813896
# [56]	train-mlogloss:0.584555	eval-mlogloss:0.812332
# [57]	train-mlogloss:0.581081	eval-mlogloss:0.811194
# [58]	train-mlogloss:0.578144	eval-mlogloss:0.810262
# [59]	train-mlogloss:0.575177	eval-mlogloss:0.80943
# [60]	train-mlogloss:0.572067	eval-mlogloss:0.808418
# [61]	train-mlogloss:0.568668	eval-mlogloss:0.807194
# [62]	train-mlogloss:0.565932	eval-mlogloss:0.80653
# [63]	train-mlogloss:0.563169	eval-mlogloss:0.805801
# [64]	train-mlogloss:0.560318	eval-mlogloss:0.805201
# [65]	train-mlogloss:0.557647	eval-mlogloss:0.804452
# [66]	train-mlogloss:0.554861	eval-mlogloss:0.803707
# [67]	train-mlogloss:0.552079	eval-mlogloss:0.802815
# [68]	train-mlogloss:0.549564	eval-mlogloss:0.802203
# [69]	train-mlogloss:0.547053	eval-mlogloss:0.801691
# [70]	train-mlogloss:0.544544	eval-mlogloss:0.801132
# [71]	train-mlogloss:0.542129	eval-mlogloss:0.800619
# [72]	train-mlogloss:0.539398	eval-mlogloss:0.800151
# [73]	train-mlogloss:0.537403	eval-mlogloss:0.799624
# [74]	train-mlogloss:0.535143	eval-mlogloss:0.799149
# [75]	train-mlogloss:0.532983	eval-mlogloss:0.798683
# [76]	train-mlogloss:0.530566	eval-mlogloss:0.798355
# [77]	train-mlogloss:0.528416	eval-mlogloss:0.797838
# [78]	train-mlogloss:0.526196	eval-mlogloss:0.797385
# [79]	train-mlogloss:0.523737	eval-mlogloss:0.796766
# [80]	train-mlogloss:0.52164	eval-mlogloss:0.796306
# [81]	train-mlogloss:0.519055	eval-mlogloss:0.795625
# [82]	train-mlogloss:0.517081	eval-mlogloss:0.795214
# [83]	train-mlogloss:0.515203	eval-mlogloss:0.794791
# [84]	train-mlogloss:0.512943	eval-mlogloss:0.794352
# [85]	train-mlogloss:0.510789	eval-mlogloss:0.794048
# [86]	train-mlogloss:0.508458	eval-mlogloss:0.793815
# [87]	train-mlogloss:0.50633	eval-mlogloss:0.793414
# [88]	train-mlogloss:0.504309	eval-mlogloss:0.792747
# [89]	train-mlogloss:0.501656	eval-mlogloss:0.792135
# [90]	train-mlogloss:0.499465	eval-mlogloss:0.79177
# [91]	train-mlogloss:0.497524	eval-mlogloss:0.791495
# [92]	train-mlogloss:0.495177	eval-mlogloss:0.790966
# [93]	train-mlogloss:0.493262	eval-mlogloss:0.790641
# [94]	train-mlogloss:0.491439	eval-mlogloss:0.790408
# [95]	train-mlogloss:0.489629	eval-mlogloss:0.790247
# [96]	train-mlogloss:0.488085	eval-mlogloss:0.790142
# [97]	train-mlogloss:0.486302	eval-mlogloss:0.789966
# [98]	train-mlogloss:0.484435	eval-mlogloss:0.789878
# [99]	train-mlogloss:0.482598	eval-mlogloss:0.789643
# [100]	train-mlogloss:0.480678	eval-mlogloss:0.789175
# [101]	train-mlogloss:0.478916	eval-mlogloss:0.789194
# [102]	train-mlogloss:0.47723	eval-mlogloss:0.78904
# [103]	train-mlogloss:0.475517	eval-mlogloss:0.788444
# [104]	train-mlogloss:0.473911	eval-mlogloss:0.788185
# [105]	train-mlogloss:0.472047	eval-mlogloss:0.788113
# [106]	train-mlogloss:0.469932	eval-mlogloss:0.787766
# [107]	train-mlogloss:0.468121	eval-mlogloss:0.787596
# [108]	train-mlogloss:0.466331	eval-mlogloss:0.787467
# [109]	train-mlogloss:0.464658	eval-mlogloss:0.787346
# [110]	train-mlogloss:0.462924	eval-mlogloss:0.78721
# [111]	train-mlogloss:0.4611	eval-mlogloss:0.786957
# [112]	train-mlogloss:0.459449	eval-mlogloss:0.786653
# [113]	train-mlogloss:0.457553	eval-mlogloss:0.786417
# [114]	train-mlogloss:0.456076	eval-mlogloss:0.786157
# [115]	train-mlogloss:0.454513	eval-mlogloss:0.786032
# [116]	train-mlogloss:0.45305	eval-mlogloss:0.785853
# [117]	train-mlogloss:0.450888	eval-mlogloss:0.785481
# [118]	train-mlogloss:0.449386	eval-mlogloss:0.785541
# [119]	train-mlogloss:0.447647	eval-mlogloss:0.785391
# [120]	train-mlogloss:0.446069	eval-mlogloss:0.785217
# [121]	train-mlogloss:0.444368	eval-mlogloss:0.785101
# [122]	train-mlogloss:0.442756	eval-mlogloss:0.785058
# [123]	train-mlogloss:0.441212	eval-mlogloss:0.784989
# [124]	train-mlogloss:0.43949	eval-mlogloss:0.784919
# [125]	train-mlogloss:0.438015	eval-mlogloss:0.784881
# [126]	train-mlogloss:0.436361	eval-mlogloss:0.784859
# [127]	train-mlogloss:0.434884	eval-mlogloss:0.784791
# [128]	train-mlogloss:0.433523	eval-mlogloss:0.784787
# [129]	train-mlogloss:0.432036	eval-mlogloss:0.784791
# [130]	train-mlogloss:0.430249	eval-mlogloss:0.784838
# [131]	train-mlogloss:0.428359	eval-mlogloss:0.784603
# [132]	train-mlogloss:0.426769	eval-mlogloss:0.784413
# [133]	train-mlogloss:0.425521	eval-mlogloss:0.784297
# [134]	train-mlogloss:0.424158	eval-mlogloss:0.78429
# [135]	train-mlogloss:0.422801	eval-mlogloss:0.784265
# [136]	train-mlogloss:0.421325	eval-mlogloss:0.784003
# [137]	train-mlogloss:0.419453	eval-mlogloss:0.783859
# [138]	train-mlogloss:0.417939	eval-mlogloss:0.783845
# [139]	train-mlogloss:0.416661	eval-mlogloss:0.783806
# [140]	train-mlogloss:0.415363	eval-mlogloss:0.783793
# [141]	train-mlogloss:0.414027	eval-mlogloss:0.783787
# [142]	train-mlogloss:0.412825	eval-mlogloss:0.783747
# [143]	train-mlogloss:0.41142	eval-mlogloss:0.783899
# [144]	train-mlogloss:0.410029	eval-mlogloss:0.783829
# [145]	train-mlogloss:0.408149	eval-mlogloss:0.783606
# [146]	train-mlogloss:0.406699	eval-mlogloss:0.783509
# [147]	train-mlogloss:0.405316	eval-mlogloss:0.783515
# [148]	train-mlogloss:0.403888	eval-mlogloss:0.783548
# [149]	train-mlogloss:0.402443	eval-mlogloss:0.783604
# [150]	train-mlogloss:0.401104	eval-mlogloss:0.783525
# [151]	train-mlogloss:0.399913	eval-mlogloss:0.783573
# [152]	train-mlogloss:0.398603	eval-mlogloss:0.783652
# [153]	train-mlogloss:0.397375	eval-mlogloss:0.783642
# [154]	train-mlogloss:0.396088	eval-mlogloss:0.783475
# [155]	train-mlogloss:0.39493	eval-mlogloss:0.783456
# [156]	train-mlogloss:0.393398	eval-mlogloss:0.783276
# [157]	train-mlogloss:0.392094	eval-mlogloss:0.783237
# [158]	train-mlogloss:0.390581	eval-mlogloss:0.783358
# [159]	train-mlogloss:0.389361	eval-mlogloss:0.783456
# [160]	train-mlogloss:0.388136	eval-mlogloss:0.783437
# [161]	train-mlogloss:0.386852	eval-mlogloss:0.78338
# [162]	train-mlogloss:0.385491	eval-mlogloss:0.783437
# [163]	train-mlogloss:0.384328	eval-mlogloss:0.783623
# [164]	train-mlogloss:0.383129	eval-mlogloss:0.783536
# [165]	train-mlogloss:0.38194	eval-mlogloss:0.78355
# [166]	train-mlogloss:0.380664	eval-mlogloss:0.78361
# [167]	train-mlogloss:0.379214	eval-mlogloss:0.78365
# Stopping. Best iteration:
# [157]	train-mlogloss:0.392094	eval-mlogloss:0.783237

# %%
from sklearn.metrics import log_loss
my_test = xgb.DMatrix(X_test.values)
test_predictions = bst.predict(my_test)
print("log loss :", log_loss(y_test, test_predictions).round(5))
# Out:
# log loss : 0.78365

# %%
import operator
importance_dict = bst.get_score()
sorted_dict = sorted(importance_dict.items(), key=operator.itemgetter(1))
sorted_dict = sorted_dict[::-1]

indices = []
for i in range(len(sorted_dict)-1):
    indices.append(sorted_dict[i][0])
    
indices = [int(idx[1:]) for idx in indices]

importance_features = []
for idx in indices:
    importance_features.append(train.columns[idx])

importance = list(bst.get_score().values())
importance = sorted(importance)
importance = importance[::-1]

pairs = list(zip(importance, importance_features))
labels = [label[1] for label in pairs]

plt.figure(figsize=(12, 8))
plt.barh(range(20), importance[:20][::-1], align="center")
plt.yticks(np.arange(20), labels[:20][::-1])
plt.xlabel("Feature importance")
plt.ylim(-1, 20)
plt.show()

# %% [markdown]
# ##### Accuracy score

# %%
yprob = test_predictions.reshape(y_test.shape[0], 38)
ylabel = np.argmax(yprob, axis=1)
accuracy = 100 *(1 - (sum(int(ylabel[i]) != y_test[i]
                         for i in range(len(y_test))) / float(len(y_test))))
print("TripType Accuracy = %.2f%%" % accuracy)
# Out:
# TripType Accuracy = 73.73%

# %% [markdown]
# ### Submission

# %%
classes = np.array(list(set(label_enc.inverse_transform(y_labeled))))

dmtest = xgb.DMatrix(test.values) 
pred_proba = bst.predict(dmtest)

proba_df = pd.DataFrame(pred_proba, columns=classes)
proba_df.columns = proba_df.columns.map(lambda x: "TripType_" + str(x))
sub_df = pd.concat([vn, proba_df], axis=1)

sub_df.to_csv("data/team_SWYA_submission.csv", index=False)

# %% [markdown]
# <img src="https://github.com/yunah0515/dss7_SWYA_walmart/blob/master/2%ED%8C%80(SWYA)_B/data/final_score.png?raw=true">
